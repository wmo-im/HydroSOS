# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

# data from https://allisonhorst.github.io/palmerpenguins/

species = (
    "Adelie\n $\\mu=$3700.66g",
    "Chinstrap\n $\\mu=$3733.09g",
    "Gentoo\n $\\mu=5076.02g$",
)
weight_counts = {
    "Below": np.array([70, 31, 58]),
    "Above": np.array([82, 37, 66]),
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(3) + 10

for boolean, weight_count in weight_counts.items():
    p = ax.bar(species, weight_count, width, label=boolean, bottom=bottom)
    bottom += 2* weight_count

ax.set_title("Number of penguins with above average body mass")
ax.legend(loc="upper right")

plt.show()

# %%
status=np.array([1,2,2,1,4,3])
forecast={1:np.array([20,30,10,20,20]),2:np.array([30,40,10,10,10]),3:np.array([10,10,10,50,20]),4:np.array([20,50,10,20,0]),5:np.array([20,30,25,20,5])}
# Out:
#   Cell In[9], line 2
#     forecast={[1,2,3,4,5],1:np.array([20,30,10,20,20]),2:np.array([30,40,10,10,10]),3:np.array([10,10,10,50,20]),4:np.array([20,50,10,20,0]),5:np.array([20,30,25,20,5])}
#                            ^
# SyntaxError: invalid syntax

# %%
fig,axes = plt.subplots(ncols=2)
axes[0].scatter(np.arange(1,7),status)
axes[1].bar([1,2,3,4,5],forecast)
# Out:
# <BarContainer object of 5 artists>
